# %% [markdown]
# <a href="https://colab.research.google.com/github/Lahiru66/Color-Pic/blob/master/First.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import useful libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = '/content/drive/MyDrive/Data/Final.csv'
dataset = pd.read_csv(path)
dataset.head()
# Out:
#    Div      Date     HomeTeam     AwayTeam  ... BbAvAHH  BbMxAHA  BbAvAHA  FTR
# 0  SC0  6/8/2016   Kilmarnock   Motherwell  ...    1.92     1.95     1.88    A
# 1  SC0  6/8/2016      Partick  Inverness C  ...    1.90     1.97     1.90    H
# 2  SC0  6/8/2016      Rangers     Hamilton  ...    1.84     2.06     1.98    A
# 3  SC0  6/8/2016  Ross County       Dundee  ...    1.95     1.93     1.87    A
# 4  SC0  7/8/2016       Hearts       Celtic  ...    1.99     1.93     1.84    A
#
# [5 rows x 64 columns]

# %%
dataset
# Out:
#      Div        Date     HomeTeam      AwayTeam  ... BbAvAHH  BbMxAHA  BbAvAHA  FTR
# 0    SC0    6/8/2016   Kilmarnock    Motherwell  ...    1.92     1.95     1.88    A
# 1    SC0    6/8/2016      Partick   Inverness C  ...    1.90     1.97     1.90    H
# 2    SC0    6/8/2016      Rangers      Hamilton  ...    1.84     2.06     1.98    A
# 3    SC0    6/8/2016  Ross County        Dundee  ...    1.95     1.93     1.87    A
# 4    SC0    7/8/2016       Hearts        Celtic  ...    1.99     1.93     1.84    A
# ..   ...         ...          ...           ...  ...     ...      ...      ...  ...
# 679  SC0  18/05/2019     Hamilton  St Johnstone  ...    2.57     3.35     2.96    H
# 680  SC0  18/05/2019   Motherwell    Livingston  ...    2.11     3.53     3.72    H
# 681  SC0  19/05/2019       Celtic        Hearts  ...    1.23     6.93    13.33    H
# 682  SC0  19/05/2019    Hibernian      Aberdeen  ...    3.65     3.46     2.16    A
# ...

# %%
dataset.tail()
# Out:
#      Div        Date    HomeTeam      AwayTeam  ... BbAvAHH  BbMxAHA  BbAvAHA  FTR
# 679  SC0  18/05/2019    Hamilton  St Johnstone  ...    2.57     3.35     2.96    H
# 680  SC0  18/05/2019  Motherwell    Livingston  ...    2.11     3.53     3.72    H
# 681  SC0  19/05/2019      Celtic        Hearts  ...    1.23     6.93    13.33    H
# 682  SC0  19/05/2019   Hibernian      Aberdeen  ...    3.65     3.46     2.16    A
# 683  SC0  19/05/2019  Kilmarnock       Rangers  ...    3.25     3.60     2.28    H
#
# [5 rows x 64 columns]

# %%
dataset.describe()
# Out:
#          Attendence        FTHG        FTAG  ...     BbAvAHH     BbMxAHA     BbAvAHA
# count    658.000000  684.000000  684.000000  ...  684.000000  684.000000  684.000000
# mean   15024.969605    1.445906    1.185673  ...    2.425424    2.729547    2.962485
# std    17462.851249    1.281127    1.190137  ...    1.948581    1.411225    3.404570
# min     1022.000000    0.000000    0.000000  ...    1.080000    1.690000    1.130000
# 25%     3937.750000    1.000000    0.000000  ...    1.840000    1.930000    1.840000
# 50%     6097.000000    1.000000    1.000000  ...    1.950000    2.050000    1.940000
# 75%    17053.000000    2.000000    2.000000  ...    2.072500    3.370000    2.160000
# max    59259.000000    7.000000    7.000000  ...   21.780000   12.200000   39.280000
#
# [8 rows x 55 columns]

# %%
dataset.dtypes
# Out:
# Div          object
# Date         object
# HomeTeam     object
# AwayTeam     object
# Venue        object
#              ...
# BbMxAHH     float64
# BbAvAHH     float64
# BbMxAHA     float64
# BbAvAHA     float64
# FTR          object
# Length: 64, dtype: object

# %%
#plotting target classes
import seaborn as sns
sns.set_theme(style="darkgrid")
ax = sns.countplot(x="FTR",data=dataset)

# %%
#histograms
dataset.hist()
plt.show()

# %%
# scatter plot matrix
from pandas.plotting import scatter_matrix
scatter_matrix(dataset)
plt.show()
